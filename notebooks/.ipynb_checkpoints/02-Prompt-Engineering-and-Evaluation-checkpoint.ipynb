# %%
# install or upgrade required packages
# %pip install mlflow==3.3.1 langchain-openai python-dotenv --upgrade
# Out:
# Requirement already satisfied: mlflow==3.3.1 in /opt/conda/lib/python3.11/site-packages (3.3.1)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.33-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: mlflow-skinny==3.3.1 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (3.3.1)
# Requirement already satisfied: mlflow-tracing==3.3.1 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (3.3.1)
# Requirement already satisfied: Flask<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (1.12.0)
# Requirement already satisfied: cryptography<46,>=43.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (45.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (23.0.0)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (3.8.0)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (1.26.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (2.1.1)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (13.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (1.3.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (1.11.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow==3.3.1) (2.0.22)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (0.65.0)
# Requirement already satisfied: fastapi<1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (0.117.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (3.1.40)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (6.8.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (1.37.0)
# Requirement already satisfied: packaging<26 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (23.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (4.24.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (2.11.9)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.3.1->mlflow==3.3.1) (0.36.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.76 in /opt/conda/lib/python3.11/site-packages (from langchain-openai) (0.3.76)
# Collecting openai<2.0.0,>=1.104.2 (from langchain-openai)
#   Downloading openai-1.108.1-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai)
#   Downloading tiktoken-0.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow==3.3.1) (1.2.4)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.11/site-packages (from cryptography<46,>=43.0.0->mlflow==3.3.1) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow==3.3.1) (2.0.7)
# Requirement already satisfied: blinker>=1.9.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.3.1) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.3.1) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.3.1) (3.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.3.1) (2.1.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow==3.3.1) (3.1.3)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.3.1) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.3.1) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow==3.3.1) (2.8.2)
# Requirement already satisfied: langsmith>=0.3.45 in /opt/conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.4.29)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.76->langchain-openai) (1.33)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow==3.3.1) (3.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.0.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.104.2->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.104.2->langchain-openai)
#   Downloading jiter-0.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.66.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.3.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow==3.3.1) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.3.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow==3.3.1) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.3.1) (3.0.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2025.9.18)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain-openai) (3.4)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.14->cryptography<46,>=43.0.0->mlflow==3.3.1) (2.21)
# Requirement already satisfied: google-auth~=2.0 in /opt/conda/lib/python3.11/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (2.40.3)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /opt/conda/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.48.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.3.1->mlflow==3.3.1) (4.0.10)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.104.2->langchain-openai) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.76->langchain-openai) (2.4)
# Requirement already satisfied: orjson>=3.9.14 in /opt/conda/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.76->langchain-openai) (0.25.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/conda/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.1->mlflow==3.3.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.4.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==3.3.1) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.3.1->mlflow==3.3.1) (3.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.3.1->mlflow==3.3.1) (3.0.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.3.1->mlflow==3.3.1) (0.6.1)
# Downloading langchain_openai-0.3.33-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.1 MB/s eta 0:00:00
# Downloading openai-1.108.1-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.4/948.4 kB 22.3 MB/s eta 0:00:0000:01
# Downloading tiktoken-0.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.5 MB/s eta 0:00:00a 0:00:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.0/349.0 kB 17.8 MB/s eta 0:00:00
# Installing collected packages: jiter, distro, tiktoken, openai, langchain-openai
# Successfully installed distro-1.9.0 jiter-0.11.0 langchain-openai-0.3.33 openai-1.108.1 tiktoken-0.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Imports & setup
import os
import mlflow
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_openai import AzureChatOpenAI
from dotenv import load_dotenv

# Load environment variables from .env file
# Ensure you have your Azure credentials in a .env file in the project root
load_dotenv('../.env')

# --- Configuration ---
MLFLOW_TRACKING_URI = "http://mlflow:5000"
EXPERIMENT_NAME = "Building-Companion-Prompt-Engineering"
VECTOR_STORE_PATH = "../artifacts/vector_store"

# --- MLflow Setup ---
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(EXPERIMENT_NAME)

print("✅ MLflow and libraries are ready.")
print(f"Tracking experiments in: '{EXPERIMENT_NAME}'")

# %%
# load the vector store
print("Loading embedding model...")
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
embedder = HuggingFaceEmbeddings(model_name=model_name)

print(f"Loading vector store from: {VECTOR_STORE_PATH}")
db = FAISS.load_local(VECTOR_STORE_PATH, embedder, allow_dangerous_deserialization=True)
retriever = db.as_retriever()

print("✅ Knowledge base is loaded and ready.")

# %%
# Define the prompt templates
prompt_templates = {
    "legal_expert": """
    You are an AI assistant specialized in Portuguese building regulations based on the provided document.
    Use the following pieces of context to answer the question at the end.
    If you don't know the answer from the context, just say that you don't know, don't try to make up an answer.
    Provide a concise and direct answer based strictly on the provided text. Cite the article number if possible.

    Context: {context}

    Question: {question}

    Answer (in Portuguese):
    """,
    "homeowner_guide": """
    You are a helpful AI assistant for homeowners in Portugal.
    Use the information from the provided legal document to answer the user's question in a simple, easy-to-understand way.
    Explain the key points without using complex legal jargon.

    Based on the regulations: {context}

    Here is the answer to your question: {question}

    Helpful Answer (in Portuguese):
    """
}

print(f"Defined {len(prompt_templates)} prompt templates.")

# %%
# chatbot function & experiments
def run_chatbot_experiment(prompt_template, question):
    """Runs a single query against the RAG chain and returns the result."""
    llm = AzureChatOpenAI(
        deployment_name=os.getenv("AZURE_DEPLOYMENT_NAME"),
        openai_api_version="2024-02-15-preview"
    )

    prompt = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": prompt}
    )

    return qa_chain({"query": question})

# --- Let's run our experiments! ---
test_questions = [
    "Posso construir uma cave para habitação?",
    "Qual é a altura mínima para o pé-direito de uma loja comercial?",
    "Qual a largura mínima de uma escada num prédio com 4 apartamentos?"
]

for prompt_name, prompt_text in prompt_templates.items():
    with mlflow.start_run(run_name=f"prompt_test_{prompt_name}"):
        print(f"\n--- Testing Prompt: {prompt_name} ---")
        mlflow.log_param("prompt_name", prompt_name)
        mlflow.log_text(prompt_text, "prompt.txt")

        for i, question in enumerate(test_questions):
            mlflow.log_param(f"question_{i}", question)

            result = run_chatbot_experiment(prompt_text, question)
            answer = result['result']

            # Log the answer as a text artifact
            mlflow.log_text(answer, f"answer_{i}.txt")
            print(f"Q: {question}")
            print(f"A: {answer}\n")

print("✅ All experiments completed. Check the MLflow UI at http://localhost:5001")
